# %%
Masks
Images

# %%
 + '.png'

# %%
import os
path = "./brightnessMask/Images/"
# 獲取該目錄下所有檔案，存入列表中
f = os.listdir(path)
print(len(f))

print(f[0])

n = 0
i = 0
a = 520
for i in f:
    # 設定舊檔名（就是路徑+檔名）
    oldname = f[n]

    # 設定新檔名
    newname = "0"+str(a+1) + '.png'
    # 用os模組中的rename方法對檔案改名
    os.rename(path+oldname, path+newname)
    print(oldname, '======>', newname)

    n += 1
    a += 1
# Out:
# 390
# 0001
# 0001 ======> 04031
# 0002 ======> 04032
# 0003 ======> 04033
# 0004 ======> 04034
# 0005 ======> 04035
# 0006 ======> 04036
# 0007 ======> 04037
# 0008 ======> 04038
# 0009 ======> 04039
# 0010 ======> 04040
# 0011 ======> 04041
# 0012 ======> 04042
# 0013 ======> 04043
# 0014 ======> 04044
# 0015 ======> 04045
# 0016 ======> 04046
# 0017 ======> 04047
# 0018 ======> 04048
# 0019 ======> 04049
# 0020 ======> 04050
# 0021 ======> 04051
# 0022 ======> 04052
# 0023 ======> 04053
# 0024 ======> 04054
# 0025 ======> 04055
# 0026 ======> 04056
# 0027 ======> 04057
# 0028 ======> 04058
# 0029 ======> 04059
# 0030 ======> 04060
# 0031 ======> 04061
# 0032 ======> 04062
# 0033 ======> 04063
# 0034 ======> 04064
# 0035 ======> 04065
# 0036 ======> 04066
# 0037 ======> 04067
# 0038 ======> 04068
# 0039 ======> 04069
# 0040 ======> 04070
# 0041 ======> 04071
# 0042 ======> 04072
# 0043 ======> 04073
# 0044 ======> 04074
# 0045 ======> 04075
# 0046 ======> 04076
# 0047 ======> 04077
# ...
