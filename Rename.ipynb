# %%
Masks
Images

# %%
 + '.png'

# %%
import os
path = "./flipMask/Images/"
# 獲取該目錄下所有檔案，存入列表中
f = os.listdir(path)
print(len(f))

print(f[0])

n = 0
i = 0
a = 1040
for i in f:
    # 設定舊檔名（就是路徑+檔名）
    oldname = f[n]

    # 設定新檔名
    newname = "0"+str(a+1) + '.png'
    # 用os模組中的rename方法對檔案改名
    os.rename(path+oldname, path+newname)
    print(oldname, '======>', newname)

    n += 1
    a += 1
# Out:
# 520
# 0001.png
# 0001.png ======> 01041.png
# 0002.png ======> 01042.png
# 0003.png ======> 01043.png
# 0004.png ======> 01044.png
# 0005.png ======> 01045.png
# 0006.png ======> 01046.png
# 0007.png ======> 01047.png
# 0008.png ======> 01048.png
# 0009.png ======> 01049.png
# 0010.png ======> 01050.png
# 0011.png ======> 01051.png
# 0012.png ======> 01052.png
# 0013.png ======> 01053.png
# 0014.png ======> 01054.png
# 0015.png ======> 01055.png
# 0016.png ======> 01056.png
# 0017.png ======> 01057.png
# 0018.png ======> 01058.png
# 0019.png ======> 01059.png
# 0020.png ======> 01060.png
# 0021.png ======> 01061.png
# 0022.png ======> 01062.png
# 0023.png ======> 01063.png
# 0024.png ======> 01064.png
# 0025.png ======> 01065.png
# 0026.png ======> 01066.png
# 0027.png ======> 01067.png
# 0028.png ======> 01068.png
# 0029.png ======> 01069.png
# 0030.png ======> 01070.png
# 0031.png ======> 01071.png
# 0032.png ======> 01072.png
# 0033.png ======> 01073.png
# ...
